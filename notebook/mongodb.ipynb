# %% [markdown]
# ### Getting Started with mongo connection.

# %%
import pandas as pd
import pymongo

# %%
connection_string="mongodb+srv://uae-hosuing:uae123housing@cluster0.k847eqc.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"

# %%
df=pd.read_csv(r"P:\webscraper-UAE-housing\Dataset\uae-housing_dataset.csv")
df.head()
# Out:
#        price bedroom bathroom  area(sqft) country    city  \
# 0  1,800,000  3 beds  4 baths  1,208 sqft     UAE   Dubai
# 1    325,000  Studio   1 bath    483 sqft     UAE   Dubai
# 2    470,000  Studio   1 bath    428 sqft     UAE   Dubai
# 3  1,120,000   1 bed   1 bath    706 sqft     UAE   Dubai
# 4  2,127,888  2 beds  2 baths  1,149 sqft     UAE   Dubai
#
#                            address propert_type purpose   furnishing  \
# 0   DAMAC Hills 2 (Akoya by DAMAC)    Townhouse    Sale  Unfurnished
# 1               International City    Apartment    Sale  Unfurnished
# 2                            Arjan    Apartment    Sale    Furnished
# 3                      Dubai South    Apartment    Sale  Unfurnished
# 4                      Dubai South    Apartment    Sale  Unfurnished
#
#   completion_status handover    project_name
# 0          Off-Plan  Q2 2025  Camelia Villas
# 1             Ready  Q2 2025  Camelia Villas
# 2             Ready  Q2 2025  Camelia Villas
# ...

# %%
data=df.to_dict(orient="records")

# %%
data
# Out:
# [{'price': '1,800,000',
#   'bedroom': '3 beds',
#   'bathroom': '4 baths',
#   'area(sqft)': '1,208 sqft',
#   'country': ' UAE',
#   'city': ' Dubai',
#   'address': ' DAMAC Hills 2 (Akoya by DAMAC)',
#   'propert_type': 'Townhouse',
#   'purpose': 'Sale',
#   'furnishing': 'Unfurnished',
#   'completion_status': 'Off-Plan',
#   'handover': 'Q2 2025',
#   'project_name': 'Camelia Villas'},
#  {'price': '325,000',
#   'bedroom': 'Studio',
#   'bathroom': '1 bath',
#   'area(sqft)': '483 sqft',
#   'country': ' UAE',
#   'city': ' Dubai',
#   'address': ' International City',
#   'propert_type': 'Apartment',
#   'purpose': 'Sale',
#   'furnishing': 'Unfurnished',
#   'completion_status': 'Ready',
#   'handover': 'Q2 2025',
#   'project_name': 'Camelia Villas'},
#  {'price': '470,000',
#   'bedroom': 'Studio',
#   'bathroom': '1 bath',
#   'area(sqft)': '428 sqft',
#   'country': ' UAE',
#   'city': ' Dubai',
#   'address': ' Arjan',
#   'propert_type': 'Apartment',
# ...

# %%
Database_Name="UAE-housing"
Collection="uaedata"
connection_url="mongodb+srv://uae-hosuing:uae123housing@cluster0.k847eqc.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"

# %%
import pymongo

import certifi
client=pymongo.MongoClient(connection_url,tlsCAFile=certifi.where())
database=client[Database_Name]
collection=database[Collection]

# %%
#collection.insert_many(data)

# %%
db_data=collection.find()

# %%
df=pd.DataFrame(list(collection.find()))

# %%
import pandas as pd

# %%
df.drop(columns="_id")
# Out:
#           price bedroom bathroom  area(sqft) country    city  \
# 0     1,800,000  3 beds  4 baths  1,208 sqft     UAE   Dubai
# 1       325,000  Studio   1 bath    483 sqft     UAE   Dubai
# 2       470,000  Studio   1 bath    428 sqft     UAE   Dubai
# 3     1,120,000   1 bed   1 bath    706 sqft     UAE   Dubai
# 4     2,127,888  2 beds  2 baths  1,149 sqft     UAE   Dubai
# ...         ...     ...      ...         ...     ...     ...
# 5373    795,000   1 bed  2 baths    801 sqft     UAE   Dubai
# 5374    600,000  Studio   1 bath    415 sqft     UAE   Dubai
# 5375  2,062,632   1 bed  2 baths    688 sqft     UAE   Dubai
# 5376  4,750,000  2 beds  3 baths  1,329 sqft     UAE   Dubai
# 5377  1,250,000  Studio   1 bath    544 sqft     UAE   Dubai
#
#                               address propert_type purpose   furnishing  \
# 0      DAMAC Hills 2 (Akoya by DAMAC)    Townhouse    Sale  Unfurnished
# 1                  International City    Apartment    Sale  Unfurnished
# ...

# %%
df
# Out:
#                            _id      price bedroom bathroom  area(sqft)  \
# 0     67f8829087aba3bf2980b187  1,800,000  3 beds  4 baths  1,208 sqft
# 1     67f8829087aba3bf2980b188    325,000  Studio   1 bath    483 sqft
# 2     67f8829087aba3bf2980b189    470,000  Studio   1 bath    428 sqft
# 3     67f8829087aba3bf2980b18a  1,120,000   1 bed   1 bath    706 sqft
# 4     67f8829087aba3bf2980b18b  2,127,888  2 beds  2 baths  1,149 sqft
# ...                        ...        ...     ...      ...         ...
# 5373  67f8829287aba3bf2980c684    795,000   1 bed  2 baths    801 sqft
# 5374  67f8829287aba3bf2980c685    600,000  Studio   1 bath    415 sqft
# 5375  67f8829287aba3bf2980c686  2,062,632   1 bed  2 baths    688 sqft
# 5376  67f8829287aba3bf2980c687  4,750,000  2 beds  3 baths  1,329 sqft
# 5377  67f8829287aba3bf2980c688  1,250,000  Studio   1 bath    544 sqft
#
#      country    city                          address propert_type purpose  \
# ...
